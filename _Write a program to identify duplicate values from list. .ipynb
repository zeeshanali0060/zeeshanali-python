# %% [markdown]
# #    Write a program to identify duplicate values from list.

# %%
list=[1,2,3,4,5,2,3,4,7,9,5]
l1=[]
for i in list:
    if i not in l1:
        l1.append(i)
    else:
        print(i,end=' ')
# Out:
# 2 3 4 5
