# %%
#10. Write a Python program to sum all the numeric items in a list? 
lst = []
num = int(input('How many numbers?: '))
for n in range(num):
    numbers = int(input('Enter number: '))
    lst.append(numbers)
print("Sum of elements in given list is :", sum(lst));
# Out:
# How many numbers?: 5
# Enter number: 67
# Enter number: 98
# Enter number: 90
# Enter number: 56
# Enter number: 65
# Sum of elements in given list is : 376
