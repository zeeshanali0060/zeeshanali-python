# %%
# 3. Write a Python program to display the current date and time.
from datetime import date
current_date = date.today();
print(("today's date is ",current_date));
# Out:
# ("today's date is ", datetime.date(2021, 10, 24))
