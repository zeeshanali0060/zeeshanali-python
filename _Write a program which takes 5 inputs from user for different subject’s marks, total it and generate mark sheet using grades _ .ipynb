# %%
 #7. Write a program which takes 5 inputs from user for different subject’s marks, total it and generate mark sheet using grades ? 
subj1=int(input("Enter marks of the Math: "))
subj2=int(input("Enter marks of the Urdu: "))
subj3=int(input("Enter marks of the English: "))
subj4=int(input("Enter marks of the Physics: "))
subj5=int(input("Enter marks of the Chemistry: "))
totalmarks=(subj1+subj2+subj3+subj4+subj4);
print(totalmarks);
if(totalmarks>=90):
    print("Grade: A");
elif(int(totalmarks>=80&avg<90)):
    print("Grade: B");
elif(totalmarks>=70&totalmarks<80):
    print("Grade: C")
elif(totalmarks>=60&totalmarks<70):
    print("Grade: D");
else:
    print("Grade: F");
# Out:
# Enter marks of the Math: 67
# Enter marks of the Urdu: 78
# Enter marks of the English: 89
# Enter marks of the Physics: 90
# Enter marks of the Chemistry: 45
# 414
# Grade: A
